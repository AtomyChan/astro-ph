# %% [markdown]
# # MANGA-8452-12703

# %% [markdown]
# # Type II

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
plt.rcParams['figure.dpi'] = 100.0
plt.rcParams['figure.facecolor'] = 'w'
plt.rcParams['font.family'] = 'serif'
plt.rcParams['font.size'] = 12.0

# %%
profile1 = pd.read_csv('galaxy-5-r-free.txt', sep='\s+')[1:]
profile2 = pd.read_csv('galaxy-5-g-free.txt', sep='\s+')[1:]

# %%
fig = plt.figure(figsize=(8,6))

SMA = np.array(profile1['SMA'][1:], dtype='float')
MAG = np.array(profile1['MAG'][1:], dtype='float')
lower_error = np.array(profile1['MAG_LERR'][1:], dtype='float')
upper_error = np.array(profile1['MAG_UERR'][1:], dtype='float')
asymmetric_error = [lower_error, upper_error]
plt.errorbar(SMA, MAG-3, yerr=asymmetric_error, fmt='*', markersize=5, capsize=3, c='r', label='Fixed e, PA')

SMA = np.array(profile2['SMA'][1:], dtype='float')
MAG = np.array(profile2['MAG'][1:], dtype='float')
lower_error = np.array(profile2['MAG_LERR'][1:], dtype='float')
upper_error = np.array(profile2['MAG_UERR'][1:], dtype='float')
asymmetric_error = [lower_error, upper_error]
plt.errorbar(SMA, MAG, yerr=asymmetric_error, fmt='*', markersize=5, capsize=3, c='g', label='Fixed e, PA')



plt.gca().invert_yaxis()
plt.xlabel('Radius (pixel)')
plt.ylabel("MAG")
plt.legend()
plt.show()
