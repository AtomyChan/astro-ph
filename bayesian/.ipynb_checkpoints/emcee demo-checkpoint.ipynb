# %%
import numpy as np
import matplotlib.pyplot as plt
# Choose the "true" parameters.
a_true = -0.9594
b_true = 4.294
f_true = 0.534

# Generate some synthetic data from the model.
N = 50
x = np.sort(10*np.random.rand(N))
yerr = 0.1+0.5*np.random.rand(N)
y = a_true*x+b_true
y += np.abs(f_true*y) * np.random.randn(N)
y += yerr * np.random.randn(N)

# %%
# Plot these dots
fig, ax=plt.subplots(1,1)
plt.errorbar(x, y, yerr=yerr, fmt='.k')
plt.show()

# %% [markdown]
# ## Least Square Method

# %%
# Least Square Method
A = np.vstack((np.ones_like(x), x)).T
C = np.diag(yerr * yerr)
cov = np.linalg.inv(np.dot(A.T, np.linalg.solve(C, A)))
b_ls, a_ls = np.dot(cov, np.dot(A.T, np.linalg.solve(C, y)))

# %%
# Plot these dots
fig, ax=plt.subplots(1,1)
plt.errorbar(x, y, yerr=yerr, fmt='.k')
plt.plot(x, a_true*x+b_true, 'r', label='True')
plt.plot(x, a_ls*x+b_ls, '-', label='LSM')
plt.legend()
plt.show()

# %% [markdown]
# ## Minimzing Likelihood Method

# %%
def model(theta, x):
    return theta[0]*x+theta[1]

def lnLikelihood(theta, x, y, yerr):
    a, b, lnf = theta
    model_value = model(theta, x)
    inv = 1/(yerr**2 + (model_value**2 * np.exp(2*lnf)))
    inv = inv/(2*np.pi)
    return -0.5*np.sum(inv*(model_value-y)**2)+0.5*np.sum(np.log(inv))

def lnPrior(theta):
    a, b, lnf = theta
    if -5<a<5 and -5<b<5 and -10<lnf<1:
        return 0.0
    return -np.inf

def lnProb(theta, x, y, yerr):
    prior = lnPrior(theta)
    if ~np.isfinite(prior):
        return -np.inf
    return prior + lnLikelihood(theta, x, y, yerr)

import scipy.optimize as op
# We are MAXIMIZING lnProb, i.e. MINIMIZING -lnProb, 
#so for convenience we use lambda to define a temporary function nll.
nll = lambda *args: -lnProb(*args)
result = op.minimize(nll, [a_true, b_true, 0], args=(x, y, yerr))
a_ml, b_ml, lnf_ml = result["x"]
print(result['x'])
# Out:
# [-0.7938508   3.62862033 -1.29305675]

# %%
# Plot these dots
fig, ax=plt.subplots(1,1)
plt.errorbar(x, y, yerr=yerr, fmt='.k')
plt.plot(x, a_true*x+b_true, 'r', label='True')
plt.plot(x, a_ls*x+b_ls, '-', label='LSM')
plt.plot(x, a_ml*x+b_ml, 'b--', label='MLM')
plt.legend()
plt.show()

# %% [markdown]
# ## MCMC

# %%
ndim, nwalkers = 3, 100
#pos = [[a_ml, b_ml, lnf_ml] + 1e-3*np.random.randn(ndim) for i in range(nwalkers)]
pos = emcee.utils.sample_ball([a_ml, b_ml, lnf_ml], [1e-3 for i in range(ndim)], size=nwalkers)
import emcee
sampler = emcee.EnsembleSampler(nwalkers, ndim, lnProb, args=(x, y, yerr))
step = 500
pos, prob, state = sampler.run_mcmc(pos, step)

# %%
samples = sampler.chain[:,-300:,:].reshape((-1,ndim))
samples = sampler.flatchain
#sampler.reset()
print("Mean acceptance fraction: {0:.3f}"
                .format(np.mean(sampler.acceptance_fraction)))
# Out:
# Mean acceptance fraction: 0.648

# %%
fig = plt.figure(figsize=(8,8))
ax1 = plt.subplot2grid((3,1),(0,0))
plt.plot(samples[:,0])
ax2 = plt.subplot2grid((3,1),(1,0))
plt.plot(samples[:,1])
ax3 = plt.subplot2grid((3,1),(2,0))
plt.plot(samples[:,2])
plt.show()

# %%
fig, ax = plt.subplots(1, 3, sharey=True, figsize=(8,4))
for i in range(ndim):
    ax[i].hist(sampler.flatchain[:,i], 100, color="k", histtype="step")
    ax[i].set_title("Dimension {0:d}".format(i))
plt.show()

# %%
import corner
fig = corner.corner(samples, labels=["$a$", "$b$", "$\ln\,f$"],
                      truths=[a_ml, b_ml, lnf_ml])

# %%
emcee.autocorr.integrated_time(samples.T[0])
# Out:
# 39.27370533240287

# %%
xl = np.array([0, 9])
for a, b, lnf in samples[np.random.randint(len(samples), size=100)]:
    plt.plot(xl, a*xl+b, color="k", alpha=0.1)

plt.errorbar(x, y, yerr=yerr, fmt=".k")
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
samples[:, 2] = np.exp(samples[:, 2])
a_mcmc, b_mcmc, f_mcmc = map(lambda v: (v[1], v[2]-v[1], v[1]-v[0]),
                             zip(*np.percentile(samples, [16, 50, 84],
                                                axis=0)))

# %%
print(a_mcmc, b_mcmc, f_mcmc)
# Out:
# (-0.805294004844112, 0.09266151216778307, 0.09381640428256666) (3.6546083378894063, 0.5266948246292089, 0.4705347334951564) (0.277143776412095, 0.05572614591848424, 0.04122517035353168)
